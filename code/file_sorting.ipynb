# %%
# local images 
# train 
# validation 

import glob
import os

os.chdir('/Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/dataset/wikiart/')
for file in glob.glob('*/claude-monet*.*'):
    print(file) 

os.chdir('/Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/dataset/wikiart/')
for file in glob.glob('*/pablo-picasso*.*'):
    print(file)

Analytical_Cubism = 0
Expressionism = 0
Art_Nouveau_Modern = 0 
Symbolism = 0 
Realism =0
Cubism = 0
Impressionism = 0
Post_Impressionism = 0 
Pointillism = 0
Synthetic_Cubism = 0
Naive_Art_Primitivism = 0 
for file in glob.glob('/Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/data/wikiart/Analytical_Cubism/pablo-picasso*.*'):
    Analytical_Cubism_Count +=1   
print("Analytical_Cubism_Count" , Analytical_Cubism_Count)
era_list = ["Analytical_Cubism","Expressionism","Art_Nouveau_Modern","Symbolism","Realism","Cubism","Impressionism","Post_Impressionism","Pointillism","Synthetic_Cubism","Naive_Art_Primitivism"]
era_counts = [0] * 11
count = 0
for i in era_list:
    for file in glob.glob('/Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/data/wikiart/' +i+ '/pablo-picasso*.*'):
        era_counts[count] +=1   

    print(i , era_counts[count])
    count =+1

era_list = ["Realism","Impressionism"]
era_counts = [0] * 2
count = 0
for i in era_list:
    for file in glob.glob('/Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/data/wikiart/' +i+ '/claude-monet*.*'):
        era_counts[count] +=1   

    print(i , era_counts[count])
    count =+1
# Out:
# Realism/claude-monet_the-chapel-notre-dame-de-grace-at-honfleur.jpg
# Realism/claude-monet_portrait-of-madame-gaudibert.jpg
# Realism/claude-monet_pont-of-honfleur-sun.jpg
# Realism/claude-monet_by-the-sea.jpg
# Realism/claude-monet_still-life-with-bottles-1863.jpg
# Realism/claude-monet_a-corner-of-the-studio(1).jpg
# Realism/claude-monet_the-luncheon.jpg
# Realism/claude-monet_the-road-from-chailly-to-fontainebleau.jpg
# Realism/claude-monet_trophies-of-the-hunt.jpg
# Realism/claude-monet_a-farmyard-in-normandy(1).jpg
# Realism/claude-monet_camille-also-known-as-the-woman-in-a-green-dress.jpg
# Realism/claude-monet_the-garden-of-the-princess-1867.jpg
# Realism/claude-monet_view-at-rouelles-le-havre.jpg
# Realism/claude-monet_camille-with-a-small-dog.jpg
# Impressionism/claude-monet_morning-on-the-seine-near-giverny-02.jpg
# Impressionism/claude-monet_the-plain-of-colombes-white-frost-1873.jpg
# Impressionism/claude-monet_not_detected_212141.jpg
# ...
