# %%
import tensorflow as tf
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
import numpy as np
import os
import glob 

# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')

# for each Monet painting, we see what objects are predominantly in the paintings
# Load an image (replace 'painting.jpg' with your image file)
monet_subjects = []
current_dir = os.getcwd()
print(current_dir)
train_images_folder = os.path.abspath(os.path.join(current_dir, '..', 'presplit_data/train/monet'))
validation_images_folder = os.path.abspath(os.path.join(current_dir, '..', 'presplit_data/validation/monet'))
#for file in glob.glob(os.path.join(train_images_folder, "/*")):
subjects = []
os.chdir(os.path.join( train_images_folder) 

for file in glob.glob('*.jpg'):
    print(file)
    img_path = os.path.join(train_images_folder , file )
    print(img_path)
    img = image.load_img(img_path, target_size=(224, 224))  # Resize to ResNet50's input size
    img_array = image.img_to_array(img)  # Convert image to a numpy array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Preprocess the image as expected by ResNet50

    # Predict the object class probabilities
    predictions = model.predict(img_array)

    # Decode and print the top 3 predicted classes
    decoded_predictions = decode_predictions(predictions, top=3)[0]
    
    for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
        print(f"{i + 1}. {label}: {score:.2f}")
        subjects.append(label[0])
# Out:
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/code
# claude-monet_morning-on-the-seine-near-giverny-02.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_morning-on-the-seine-near-giverny-02.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1. geyser: 0.69
# 2. fountain: 0.05
# 3. window_screen: 0.04
# claude-monet_the-plain-of-colombes-white-frost-1873.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-plain-of-colombes-white-frost-1873.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1. fountain: 0.75
# 2. barn: 0.07
# 3. jigsaw_puzzle: 0.06
# claude-monet_not_detected_212141.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_not_detected_212141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. fountain: 0.14
# 2. dishrag: 0.14
# 3. palace: 0.13
# claude-monet_river-thawing-near-vetheuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_river-thawing-near-vetheuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1. lakeside: 0.29
# 2. geyser: 0.17
# 3. valley: 0.10
# claude-monet_farmyard.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_farmyard.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. stone_wall: 0.66
# 2. castle: 0.20
# 3. megalith: 0.04
# claude-monet_landscape-at-port-villez-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_landscape-at-port-villez-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1. valley: 0.25
# 2. stone_wall: 0.16
# 3. lakeside: 0.15
# claude-monet_view-of-rouen.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_view-of-rouen.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. gondola: 0.67
# 2. dock: 0.13
# 3. wreck: 0.07
# claude-monet_mount-kolsaas.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_mount-kolsaas.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1. alp: 0.60
# 2. American_alligator: 0.08
# 3. fountain: 0.04
# claude-monet_view-of-cap-d-antibes.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_view-of-cap-d-antibes.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1. jigsaw_puzzle: 0.28
# 2. barn: 0.20
# 3. fountain: 0.09
# claude-monet_antibes-seen-from-the-salis-gardens-02(1).jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_antibes-seen-from-the-salis-gardens-02(1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1. fountain: 0.37
# 2. barn: 0.21
# 3. lakeside: 0.21
# claude-monet_the-garden-hollyhocks.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-garden-hollyhocks.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1. castle: 0.20
# 2. valley: 0.15
# 3. stone_wall: 0.09
# claude-monet_hauling-a-boat-ashore-honfleur.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_hauling-a-boat-ashore-honfleur.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1. wreck: 0.71
# 2. cliff: 0.10
# 3. lakeside: 0.05
# claude-monet_the-hamlet-of-chantemesie-at-the-foot-of-the-rock.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-hamlet-of-chantemesie-at-the-foot-of-the-rock.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1. jigsaw_puzzle: 0.20
# 2. megalith: 0.10
# 3. fountain: 0.07
# claude-monet_the-rock-needle-and-the-porte-d-aval-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-rock-needle-and-the-porte-d-aval-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. jigsaw_puzzle: 0.80
# 2. cliff: 0.05
# 3. fountain: 0.04
# claude-monet_haystacks-white-frost-sunrise.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_haystacks-white-frost-sunrise.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. fountain: 0.94
# 2. jigsaw_puzzle: 0.04
# 3. barn: 0.01
# claude-monet_water-lilies-red-1919.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-red-1919.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1. coral_reef: 0.70
# 2. jigsaw_puzzle: 0.26
# 3. handkerchief: 0.00
# claude-monet_rouen-cathedral-the-portal-morning-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_rouen-cathedral-the-portal-morning-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. fountain: 0.55
# 2. jigsaw_puzzle: 0.18
# 3. window_screen: 0.13
# claude-monet_anglers-on-the-seine-at-poissy(1).jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_anglers-on-the-seine-at-poissy(1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1. wreck: 0.41
# 2. gondola: 0.17
# 3. book_jacket: 0.13
# claude-monet_gladiolus-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_gladiolus-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1. vase: 0.92
# 2. pot: 0.07
# 3. dining_table: 0.01
# claude-monet_water-lilies-18.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1. geyser: 0.59
# 2. jigsaw_puzzle: 0.09
# 3. valley: 0.07
# claude-monet_grainstacks.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_grainstacks.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1. fountain: 0.58
# 2. hay: 0.15
# 3. shovel: 0.07
# claude-monet_valley-bouna-near-bordighera.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_valley-bouna-near-bordighera.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1. alp: 0.50
# 2. valley: 0.45
# 3. coral_reef: 0.01
# claude-monet_water-lilies-24.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-24.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1. lakeside: 0.47
# 2. geyser: 0.14
# 3. volcano: 0.05
# claude-monet_the-church-at-varengeville.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-church-at-varengeville.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1. cliff: 0.91
# 2. alp: 0.02
# 3. fountain: 0.02
# claude-monet_apple-trees-in-blossom-by-the-water(1).jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_apple-trees-in-blossom-by-the-water(1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1. chain: 0.20
# 2. honeycomb: 0.19
# 3. alligator_lizard: 0.12
# claude-monet_houses-at-falaise-in-the-fog.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_houses-at-falaise-in-the-fog.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1. milk_can: 0.85
# 2. tray: 0.04
# 3. jigsaw_puzzle: 0.02
# claude-monet_the-artist-s-house-at-giverny.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-artist-s-house-at-giverny.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1. castle: 0.33
# 2. cliff: 0.11
# 3. monastery: 0.10
# claude-monet_palazzo-da-mulla.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_palazzo-da-mulla.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. fountain: 0.36
# 2. palace: 0.12
# 3. castle: 0.08
# claude-monet_waterloo-bridge-dawn-1901.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_waterloo-bridge-dawn-1901.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1. velvet: 0.72
# 2. window_screen: 0.09
# 3. stingray: 0.04
# claude-monet_the-japanese-bridge-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-japanese-bridge-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1. shovel: 0.14
# 2. fountain: 0.13
# 3. barrel: 0.07
# claude-monet_view-of-ventimiglia-1884.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_view-of-ventimiglia-1884.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1. volcano: 0.18
# 2. promontory: 0.13
# 3. lakeside: 0.08
# claude-monet_isleets-at-port-villez.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_isleets-at-port-villez.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1. castle: 0.22
# 2. valley: 0.08
# 3. barn: 0.07
# claude-monet_vetheuil-the-church-in-winter.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vetheuil-the-church-in-winter.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1. stupa: 0.32
# 2. jigsaw_puzzle: 0.18
# 3. apiary: 0.04
# claude-monet_houses-in-the-snow-norway.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_houses-in-the-snow-norway.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. tick: 0.30
# 2. ant: 0.25
# 3. nail: 0.05
# claude-monet_vetheuil-in-winter.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vetheuil-in-winter.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1. jigsaw_puzzle: 0.50
# 2. fountain: 0.16
# 3. geyser: 0.12
# claude-monet_vetheuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vetheuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1. jigsaw_puzzle: 0.74
# 2. castle: 0.21
# 3. lakeside: 0.03
# claude-monet_cliffs-at-pourville-morning.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_cliffs-at-pourville-morning.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1. fountain: 0.97
# 2. bubble: 0.01
# 3. geyser: 0.00
# claude-monet_pathway-in-monet-s-garden-at-giverny.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_pathway-in-monet-s-garden-at-giverny.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. prayer_rug: 0.54
# 2. tile_roof: 0.15
# 3. quilt: 0.11
# claude-monet_portrait-of-eugenie-graff-madame-paul-1882.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_portrait-of-eugenie-graff-madame-paul-1882.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1. Yorkshire_terrier: 0.46
# 2. silky_terrier: 0.05
# 3. vestment: 0.04
# claude-monet_the-garden-gate.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-garden-gate.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1. jigsaw_puzzle: 0.50
# 2. fountain: 0.20
# 3. chainlink_fence: 0.13
# claude-monet_the-japanese-bridge-1924-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-japanese-bridge-1924-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1. barn: 0.25
# 2. meat_loaf: 0.20
# 3. park_bench: 0.05
# claude-monet_the-seine-at-vetheuil-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-at-vetheuil-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. coral_reef: 0.24
# 2. lakeside: 0.22
# 3. valley: 0.18
# claude-monet_jerusalem-artichokes.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_jerusalem-artichokes.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. pot: 0.36
# 2. jigsaw_puzzle: 0.24
# 3. vase: 0.07
# claude-monet_adolphe-monet-reading-in-the-garden(1).jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_adolphe-monet-reading-in-the-garden(1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1. Cardigan: 0.17
# 2. malamute: 0.16
# 3. groenendael: 0.10
# claude-monet_waterloo-bridge-1902.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_waterloo-bridge-1902.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1. viaduct: 0.45
# 2. castle: 0.15
# 3. jigsaw_puzzle: 0.08
# claude-monet_morning-on-the-seine-2.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_morning-on-the-seine-2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. jigsaw_puzzle: 0.81
# 2. fountain: 0.07
# 3. lakeside: 0.02
# claude-monet_water-lilies-31.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1. jigsaw_puzzle: 0.40
# 2. tray: 0.24
# 3. fountain: 0.09
# claude-monet_white-clematis-1887.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_white-clematis-1887.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1. coral_fungus: 0.62
# 2. daisy: 0.18
# 3. coral_reef: 0.03
# claude-monet_water-lilies-19.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1. geyser: 0.80
# 2. valley: 0.06
# 3. fountain: 0.03
# claude-monet_portrait-of-madame-gaudibert.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_portrait-of-madame-gaudibert.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1. yurt: 0.42
# 2. hoopskirt: 0.13
# 3. mosquito_net: 0.13
# claude-monet_the-pond-at-montgeron.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-pond-at-montgeron.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1. window_screen: 0.36
# 2. chainlink_fence: 0.14
# 3. stone_wall: 0.06
# claude-monet_bennecourt.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_bennecourt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. castle: 0.90
# 2. monastery: 0.06
# 3. church: 0.03
# claude-monet_water-lilies-1917-5.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-1917-5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. jigsaw_puzzle: 0.52
# 2. lakeside: 0.21
# 3. fountain: 0.12
# claude-monet_regatta-at-sainte-adresse.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_regatta-at-sainte-adresse.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1. wreck: 0.31
# 2. fountain: 0.14
# 3. seashore: 0.09
# claude-monet_evening-at-argenteuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_evening-at-argenteuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1. castle: 0.38
# 2. barn: 0.21
# 3. viaduct: 0.05
# claude-monet_the-studio-boat.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-studio-boat.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1. boathouse: 0.60
# 2. fountain: 0.21
# 3. lakeside: 0.03
# claude-monet_vernon-church-in-fog-1893.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vernon-church-in-fog-1893.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1. castle: 0.68
# 2. window_screen: 0.19
# 3. barn: 0.03
# claude-monet_the-grand-dock-at-le-havre-1872.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-grand-dock-at-le-havre-1872.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1. jigsaw_puzzle: 0.35
# 2. monastery: 0.15
# 3. dome: 0.10
# claude-monet_snow-at-argenteuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_snow-at-argenteuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. picket_fence: 0.28
# 2. stone_wall: 0.18
# 3. chainlink_fence: 0.13
# claude-monet_water-lilies-green-reflection-left-half-1926.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-green-reflection-left-half-1926.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1. cliff: 0.95
# 2. valley: 0.01
# 3. alp: 0.00
# claude-monet_snow-effect-at-limetz-1886.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_snow-effect-at-limetz-1886.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1. castle: 0.36
# 2. church: 0.19
# 3. monastery: 0.07
# claude-monet_mediteranian-coast-grey-day.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_mediteranian-coast-grey-day.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1. stone_wall: 0.13
# 2. lakeside: 0.06
# 3. fountain: 0.06
# claude-monet_not_detected_212140.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_not_detected_212140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1. castle: 0.50
# 2. cliff: 0.31
# 3. triceratops: 0.02
# claude-monet_not_detected_212142.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_not_detected_212142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1. viaduct: 0.70
# 2. pier: 0.15
# 3. steel_arch_bridge: 0.02
# claude-monet_the-river-epte.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-river-epte.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. lakeside: 0.46
# 2. barn: 0.18
# 3. fountain: 0.11
# claude-monet_stormy-seascape-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_stormy-seascape-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1. screw: 0.28
# 2. wreck: 0.15
# 3. nail: 0.13
# claude-monet_water-lilies-9.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. jigsaw_puzzle: 0.95
# 2. window_screen: 0.03
# 3. pot: 0.01
# claude-monet_the-hut-at-trouville-low-tide-1881.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-hut-at-trouville-low-tide-1881.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1. castle: 0.66
# 2. sandbar: 0.06
# 3. lakeside: 0.04
# claude-monet_the-gulf-of-antibes.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-gulf-of-antibes.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1. breakwater: 0.31
# 2. stone_wall: 0.17
# 3. coral_fungus: 0.11
# claude-monet_water-lilies-1917-7.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-1917-7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. jigsaw_puzzle: 0.38
# 2. promontory: 0.09
# 3. lakeside: 0.06
# claude-monet_trees-by-the-seashore-at-antibes.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_trees-by-the-seashore-at-antibes.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1. park_bench: 0.23
# 2. swing: 0.17
# 3. lakeside: 0.10
# claude-monet_poplars-wind-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_poplars-wind-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1. lakeside: 0.62
# 2. totem_pole: 0.04
# 3. stone_wall: 0.03
# claude-monet_vetheuil-seen-from-ile-saint-martin.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vetheuil-seen-from-ile-saint-martin.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1. lakeside: 0.23
# 2. valley: 0.10
# 3. castle: 0.10
# claude-monet_view-of-le-havre-1873.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_view-of-le-havre-1873.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1. cliff: 0.40
# 2. castle: 0.21
# 3. promontory: 0.08
# claude-monet_water-lilies-27.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-27.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1. fountain: 0.14
# 2. lakeside: 0.06
# 3. valley: 0.05
# claude-monet_water-lilies-33.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. tray: 0.91
# 2. envelope: 0.04
# 3. book_jacket: 0.01
# claude-monet_floating-ice-on-the-seine.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_floating-ice-on-the-seine.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1. jigsaw_puzzle: 0.91
# 2. maze: 0.05
# 3. geyser: 0.01
# claude-monet_the-seine-at-vetheuil-2-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-at-vetheuil-2-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. castle: 0.16
# 2. lakeside: 0.13
# 3. geyser: 0.12
# claude-monet_the-banks-of-the-seine-at-the-argenteuil-bridge.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-banks-of-the-seine-at-the-argenteuil-bridge.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1. jigsaw_puzzle: 0.64
# 2. chainlink_fence: 0.05
# 3. fountain: 0.05
# claude-monet_pheasants-and-plovers.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_pheasants-and-plovers.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1. badger: 0.60
# 2. otter: 0.09
# 3. brown_bear: 0.09
# claude-monet_portrait-of-jean-monet-wearing-a-hat-with-a-pompom.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_portrait-of-jean-monet-wearing-a-hat-with-a-pompom.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1. bow_tie: 0.73
# 2. bonnet: 0.15
# 3. wig: 0.05
# claude-monet_the-grotto-of-port-domois.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-grotto-of-port-domois.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. fountain: 0.42
# 2. cliff: 0.39
# 3. promontory: 0.03
# claude-monet_vase-of-flowers-1882.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vase-of-flowers-1882.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1. coral_reef: 0.29
# 2. sea_anemone: 0.08
# 3. pot: 0.07
# claude-monet_vetheuil-pink-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vetheuil-pink-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. jigsaw_puzzle: 0.97
# 2. lakeside: 0.01
# 3. wreck: 0.00
# claude-monet_the-isle-grande-jatte.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-isle-grande-jatte.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. valley: 0.26
# 2. park_bench: 0.14
# 3. lakeside: 0.13
# claude-monet_the-tea-set.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-tea-set.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1. tray: 0.51
# 2. doormat: 0.10
# 3. dalmatian: 0.08
# claude-monet_portrait-of-pere-paul.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_portrait-of-pere-paul.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1. jigsaw_puzzle: 0.43
# 2. book_jacket: 0.09
# 3. Airedale: 0.06
# claude-monet_winter-at-giverny-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_winter-at-giverny-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1. geyser: 0.26
# 2. jigsaw_puzzle: 0.19
# 3. ant: 0.14
# claude-monet_meadow-at-limetz.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_meadow-at-limetz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1. fountain: 0.30
# 2. barn: 0.27
# 3. geyser: 0.25
# claude-monet_flood-of-the-seine-at-vetheuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_flood-of-the-seine-at-vetheuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1. lakeside: 0.48
# 2. jigsaw_puzzle: 0.11
# 3. valley: 0.09
# claude-monet_dahlias.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_dahlias.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. coral_reef: 0.20
# 2. tray: 0.17
# 3. jigsaw_puzzle: 0.10
# claude-monet_valley-of-the-creuse-sunlight-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_valley-of-the-creuse-sunlight-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1. valley: 0.42
# 2. promontory: 0.27
# 3. cliff: 0.23
# claude-monet_the-riverbank-at-petit-gennevilliers.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-riverbank-at-petit-gennevilliers.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1. honeycomb: 0.35
# 2. jigsaw_puzzle: 0.24
# 3. ant: 0.09
# claude-monet_winter-on-the-seine-lavacourt-1880.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_winter-on-the-seine-lavacourt-1880.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1. coyote: 0.28
# 2. window_screen: 0.17
# 3. prairie_chicken: 0.09
# claude-monet_the-japanese-bridge-1924-2.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-japanese-bridge-1924-2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1. park_bench: 0.17
# 2. worm_fence: 0.14
# 3. barn: 0.12
# claude-monet_the-seine-at-vetheuil-2.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-at-vetheuil-2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. jigsaw_puzzle: 0.66
# 2. fountain: 0.22
# 3. lakeside: 0.02
# claude-monet_rouen-cathedral-evening-harmony-in-brown-1894.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_rouen-cathedral-evening-harmony-in-brown-1894.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1. prayer_rug: 0.96
# 2. throne: 0.01
# 3. altar: 0.01
# claude-monet_the-voorzaan.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-voorzaan.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1. wreck: 0.82
# 2. drilling_platform: 0.06
# 3. church: 0.04
# claude-monet_the-lindens-of-poissy.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-lindens-of-poissy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1. jigsaw_puzzle: 0.23
# 2. valley: 0.11
# 3. alp: 0.10
# claude-monet_morning-on-the-seine-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_morning-on-the-seine-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1. coral_reef: 0.11
# 2. window_screen: 0.06
# 3. jigsaw_puzzle: 0.04
# claude-monet_poplars-four-trees.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_poplars-four-trees.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. fountain: 0.94
# 2. shower_curtain: 0.02
# 3. window_screen: 0.01
# claude-monet_valley-of-the-creuse-afternoon-sunlight.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_valley-of-the-creuse-afternoon-sunlight.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. valley: 0.20
# 2. wombat: 0.19
# 3. megalith: 0.17
# claude-monet_water-lilies-32.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1. tray: 0.38
# 2. prayer_rug: 0.28
# 3. velvet: 0.06
# claude-monet_seascape-night-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_seascape-night-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. fountain: 0.98
# 2. geyser: 0.01
# 3. grey_whale: 0.00
# claude-monet_the-japanese-bridge-the-water-lily-pond-water-irises.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-japanese-bridge-the-water-lily-pond-water-irises.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. fountain: 0.91
# 2. worm_fence: 0.01
# 3. jigsaw_puzzle: 0.01
# claude-monet_water-lilies-26.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-26.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1. lakeside: 0.26
# 2. geyser: 0.24
# 3. ant: 0.09
# claude-monet_orchard-in-bloom.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_orchard-in-bloom.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1. park_bench: 0.15
# 2. lakeside: 0.08
# 3. obelisk: 0.07
# claude-monet_vetheuil-ice-floes.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_vetheuil-ice-floes.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. grey_whale: 0.67
# 2. killer_whale: 0.16
# 3. volcano: 0.08
# claude-monet_field-of-yellow-irises-at-giverny.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_field-of-yellow-irises-at-giverny.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1. rapeseed: 0.41
# 2. hay: 0.15
# 3. bison: 0.15
# claude-monet_snow-effect-with-setting-sun-1875.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_snow-effect-with-setting-sun-1875.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1. megalith: 0.18
# 2. window_screen: 0.13
# 3. cliff: 0.10
# claude-monet_houses-on-the-zaan-river-at-zaandam.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_houses-on-the-zaan-river-at-zaandam.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1. castle: 0.30
# 2. palace: 0.30
# 3. church: 0.24
# claude-monet_the-seine-and-the-chaantemesle.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-and-the-chaantemesle.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1. valley: 0.30
# 2. alp: 0.23
# 3. cliff: 0.13
# claude-monet_spot-on-the-banks-of-the-seine.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_spot-on-the-banks-of-the-seine.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1. jigsaw_puzzle: 0.96
# 2. lakeside: 0.00
# 3. barn: 0.00
# claude-monet_garden-at-vetheuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_garden-at-vetheuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1. valley: 0.16
# 2. barn: 0.13
# 3. worm_fence: 0.12
# claude-monet_lunch-on-the-grass.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_lunch-on-the-grass.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1. banana: 0.62
# 2. coral_fungus: 0.07
# 3. buckeye: 0.02
# claude-monet_ice-on-the-siene-at-bennecourt.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_ice-on-the-siene-at-bennecourt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1. tray: 0.18
# 2. fountain: 0.10
# 3. brass: 0.09
# claude-monet_the-valley-of-sasso-bordighera.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-valley-of-sasso-bordighera.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1. coral_reef: 0.15
# 2. barn: 0.10
# 3. picket_fence: 0.07
# claude-monet_weeping-willow-1922.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_weeping-willow-1922.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. fountain: 0.44
# 2. meat_loaf: 0.17
# 3. chiton: 0.07
# claude-monet_water-lilies-1917-6.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-1917-6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1. ant: 0.51
# 2. coral_reef: 0.12
# 3. bullfrog: 0.10
# claude-monet_boats-on-the-beach-at-etretat.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_boats-on-the-beach-at-etretat.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. pot: 0.32
# 2. lakeside: 0.16
# 3. seashore: 0.10
# claude-monet_water-lilies-nympheas-1907.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-nympheas-1907.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1. geyser: 0.25
# 2. valley: 0.10
# 3. fountain: 0.08
# claude-monet_the-bay-of-antibes.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-bay-of-antibes.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1. lakeside: 0.59
# 2. fountain: 0.21
# 3. jigsaw_puzzle: 0.16
# claude-monet_the-promenade-study.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-promenade-study.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1. jigsaw_puzzle: 0.48
# 2. fountain: 0.31
# 3. cliff: 0.05
# claude-monet_the-port-of-london.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-port-of-london.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1. castle: 0.36
# 2. monastery: 0.22
# 3. wreck: 0.07
# claude-monet_seagulls-over-the-houses-of-parliament-1904.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_seagulls-over-the-houses-of-parliament-1904.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. shovel: 0.30
# 2. jigsaw_puzzle: 0.16
# 3. milk_can: 0.11
# claude-monet_water-lilies-8.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1. stone_wall: 0.18
# 2. maze: 0.15
# 3. jigsaw_puzzle: 0.12
# claude-monet_sailboats-at-sea-pourville.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_sailboats-at-sea-pourville.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1. fountain: 0.69
# 2. knot: 0.07
# 3. cliff: 0.02
# claude-monet_juan-les-pins.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_juan-les-pins.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1. lakeside: 0.32
# 2. Indian_elephant: 0.11
# 3. park_bench: 0.09
# claude-monet_cap-martin-3.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_cap-martin-3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1. coral_reef: 0.13
# 2. scuba_diver: 0.07
# 3. lakeside: 0.04
# claude-monet_on-the-beach-at-trouville-1871.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_on-the-beach-at-trouville-1871.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1. hoopskirt: 0.86
# 2. overskirt: 0.08
# 3. gown: 0.04
# claude-monet_cliff-at-pourville-2.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_cliff-at-pourville-2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1. cliff: 0.20
# 2. loggerhead: 0.17
# 3. megalith: 0.09
# claude-monet_the-thames-below-westminster-1871.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-thames-below-westminster-1871.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1. fountain: 0.27
# 2. drilling_platform: 0.26
# 3. gondola: 0.06
# claude-monet_the-cote-sauvate.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-cote-sauvate.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. stingray: 0.41
# 2. coral_reef: 0.41
# 3. conch: 0.02
# claude-monet_the-port-of-le-havre-night-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-port-of-le-havre-night-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1. church: 0.32
# 2. fountain: 0.25
# 3. altar: 0.17
# claude-monet_snow-at-argenteuil-1.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_snow-at-argenteuil-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1. cliff: 0.38
# 2. valley: 0.10
# 3. dam: 0.07
# claude-monet_charing-cross-bridge.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_charing-cross-bridge.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1. brass: 0.89
# 2. manhole_cover: 0.03
# 3. mailbox: 0.02
# claude-monet_the-seine-at-port-villez.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-at-port-villez.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1. barn: 0.24
# 2. lakeside: 0.21
# 3. fountain: 0.17
# claude-monet_rocky-coast-and-the-lion-rock-belle-ile.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_rocky-coast-and-the-lion-rock-belle-ile.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1. fountain: 0.70
# 2. breakwater: 0.06
# 3. starfish: 0.04
# claude-monet_cliff-at-petit-ailly.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_cliff-at-petit-ailly.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1. shovel: 0.26
# 2. megalith: 0.16
# 3. trilobite: 0.15
# claude-monet_cliffs-at-pourville-rain.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_cliffs-at-pourville-rain.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. window_screen: 0.48
# 2. handkerchief: 0.12
# 3. shovel: 0.07
# claude-monet_arriving-at-montegeron(1).jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_arriving-at-montegeron(1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1. lakeside: 0.27
# 2. worm_fence: 0.16
# 3. valley: 0.11
# claude-monet_water-lilies-1917-2.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-1917-2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1. jigsaw_puzzle: 0.62
# 2. coral_reef: 0.37
# 3. scuba_diver: 0.00
# claude-monet_low-tide-at-pourville.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_low-tide-at-pourville.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1. cliff: 0.72
# 2. castle: 0.06
# 3. promontory: 0.06
# claude-monet_the-beach-and-the-falaise-d-amont.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-beach-and-the-falaise-d-amont.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1. cliff: 0.27
# 2. valley: 0.23
# 3. lakeside: 0.13
# claude-monet_the-seine-at-vetheuil.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-at-vetheuil.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1. American_alligator: 0.43
# 2. fountain: 0.05
# 3. valley: 0.04
# claude-monet_water-lilies-22.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_water-lilies-22.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1. gong: 0.49
# 2. toilet_seat: 0.11
# 3. shower_cap: 0.06
# claude-monet_portrait-of-jeanne-serveau.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_portrait-of-jeanne-serveau.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1. poncho: 0.59
# 2. stole: 0.37
# 3. vestment: 0.02
# claude-monet_the-japanese-bridge-the-water-lily-pond-1899.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-japanese-bridge-the-water-lily-pond-1899.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1. fountain: 0.82
# 2. maze: 0.10
# 3. steel_arch_bridge: 0.03
# claude-monet_the-seine-at-port-villez-blue-effect.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_the-seine-at-port-villez-blue-effect.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1. geyser: 0.45
# 2. volcano: 0.16
# 3. valley: 0.10
# claude-monet_church-at-jeufosse-snowy-weather.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_church-at-jeufosse-snowy-weather.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1. church: 0.20
# 2. castle: 0.12
# 3. viaduct: 0.11
# claude-monet_springtime-in-giverny.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_springtime-in-giverny.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1. fountain: 0.41
# 2. barn: 0.30
# 3. lakeside: 0.06
# claude-monet_meadow.jpg
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/claude-monet_meadow.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1. barn: 0.22
# 2. lakeside: 0.12
# 3. ear: 0.12
# .DS_Store
# /Users/margaretsnape/Documents/Coursera/Imperial/Unstructured Data Analysis/UDA_HW4/presplit_data/train/monet/.DS_Store
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[1], line 24
#      22 img_path = os.path.join(train_images_folder , file )
#      23 print(img_path)
# ---> 24 img = image.load_img(img_path, target_size=(224, 224))  # Resize to ResNet50's input size
#      25 img_array = image.img_to_array(img)  # Convert image to a numpy array
#      26 img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
#
# File /opt/anaconda3/envs/imperial_3_11/lib/python3.11/site-packages/keras/src/utils/image_utils.py:236, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     234         path = str(path.resolve())
#     235     with open(path, "rb") as f:
# --> 236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#     238     raise TypeError(
#     239         f"path should be path-like or io.BytesIO, not {type(path)}"
#     240     )
#
# File /opt/anaconda3/envs/imperial_3_11/lib/python3.11/site-packages/PIL/Image.py:3536, in open(fp, mode, formats)
#    3534     warnings.warn(message)
#    3535 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3536 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x2b3e490d0>
